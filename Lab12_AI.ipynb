# %% [markdown]
# # Artificial Intelligence - Fall 2020 - Laboratory 12
#
# ## _Unsupervised Learning:   Hierarchical Clustering and K-Means_
#
# c: Alexandra Dobrescu <alexandramaria.digital@gmail.com>

# %% [markdown]
# ## Agglomerative Hierarchical Clustering
#
# Useful readings can be found [here](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html) and [here](https://en.wikipedia.org/wiki/Hierarchical_clustering).
#
#
# ### Short Demo

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import matplotlib.pyplot as plt

# %%
# Values extracted from the official scikit-learn documentation (check the first link).
X = np.array([[1, 2], [1, 4], [1, 0],
              [4, 2], [4, 4], [4, 0]])

# %%
X
# Out:
# array([[1, 2],
#        [1, 4],
#        [1, 0],
#        [4, 2],
#        [4, 4],
#        [4, 0]])

# %%
# Visualise data
plt.scatter(X[:,0], X[:,1])

# %%
# Agglomerative Hierarchical Clustering model with no parameters
aggl_model_demo = AgglomerativeClustering().fit(X)

# %%
aggl_model_demo
# Out:
# AgglomerativeClustering()

# %%
# Cluster labels for each point
aggl_model_demo.labels_
# Out:
# array([1, 1, 1, 0, 0, 0], dtype=int64)

# %%
# Visualise data

plt.scatter(X[:,0], X[:,1])
plt.scatter(X[aggl_model_demo.labels_,0], X[aggl_model_demo.labels_,1], c='r')

# %% [markdown]
# ### Task 0
#
# Play around with `data.txt` and:
# * Plot data before applying the _Agglomerative Hierarchical Clustering_ algorithm (**TO DO1**);
# * **TO DO2**:
#     - Define a new variable _X_ to store `data_txt`,
#     - Apply the _Agglomerative Hierarchical Clustering_ algorithm and modify its parameters for 15 clusters;
#     - Write down your observations for different values of `affinity` (_"euclidean"_ or _"manhattan"_) and `linkage` (_"ward"_ or _"complete"_);
# * Visualise the obtained clusters.
#
# _Note:_ At the end of this task, please use the `markdown` option provided in the notebook for your observations.

# %%
# Load data for this exercise
data_txt = np.loadtxt('data.txt', usecols=(0, 1), skiprows=1)

# %%
data_txt
# Out:
# array([[665845., 557965.],
#        [597173., 575538.],
#        [618600., 551446.],
#        ...,
#        [650661., 861267.],
#        [599647., 858702.],
#        [684091., 842566.]])

# %%
# TO DO1
plt.scatter(data_txt[:,0], data_txt[:,1])
# Expected Output:

# %%
# TO DO2
X = data_txt

# Define model
aggl_model_1 = AgglomerativeClustering(n_clusters = 15, affinity = 'euclidean', linkage = 'ward')

# Use the fit_predict() function
y_predict1 = aggl_model_1.fit_predict(X)

# Get the labels and use them in your plot
print(y_predict1)
labels = aggl_model_1.labels_

plt.scatter(X[y_predict1 == 0, 0], X[y_predict1 == 0, 1], s = 10, c = '#fc2403', label = 'Cluster 1')
plt.scatter(X[y_predict1 == 1, 0], X[y_predict1 == 1, 1], s = 10, c = '#fc6203', label = 'Cluster 2')
plt.scatter(X[y_predict1 == 2, 0], X[y_predict1 == 2, 1], s = 10, c = '#fcad03', label = 'Cluster 3')
plt.scatter(X[y_predict1 == 3, 0], X[y_predict1 == 3, 1], s = 10, c = '#fceb03', label = 'Cluster 4')
plt.scatter(X[y_predict1 == 4, 0], X[y_predict1 == 4, 1], s = 10, c = '#befc03', label = 'Cluster 5')
plt.scatter(X[y_predict1 == 5, 0], X[y_predict1 == 5, 1], s = 10, c = '#4afc03', label = 'Cluster 6')
plt.scatter(X[y_predict1 == 6, 0], X[y_predict1 == 6, 1], s = 10, c = '#03fc8c', label = 'Cluster 7')
plt.scatter(X[y_predict1 == 7, 0], X[y_predict1 == 7, 1], s = 10, c = '#03fcdf', label = 'Cluster 8')
plt.scatter(X[y_predict1 == 8, 0], X[y_predict1 == 8, 1], s = 10, c = '#03dbfc', label = 'Cluster 9')
plt.scatter(X[y_predict1 == 9, 0], X[y_predict1 == 9, 1], s = 10, c = '#0388fc', label = 'Cluster 10')
plt.scatter(X[y_predict1 == 10, 0], X[y_predict1 == 10, 1], s = 10, c = '#032cfc', label = 'Cluster 11')
plt.scatter(X[y_predict1 == 11, 0], X[y_predict1 == 11, 1], s = 10, c = '#7703fc', label = 'Cluster 12')
plt.scatter(X[y_predict1 == 12, 0], X[y_predict1 == 12, 1], s = 10, c = '#ad03fc', label = 'Cluster 13')
plt.scatter(X[y_predict1 == 13, 0], X[y_predict1 == 13, 1], s = 10, c = '#fc03f4', label = 'Cluster 14')
plt.scatter(X[y_predict1 == 14, 0], X[y_predict1 == 14, 1], s = 10, c = '#fc03ad', label = 'Cluster 15')
plt.show()
# Out:
# [12 12 12 ...  2  2  2]

# %%
# Define model
aggl_model_2 = AgglomerativeClustering(n_clusters = 15, affinity = 'euclidean', linkage = 'complete')

# Use the fit_predict() function
y_predict2 = aggl_model_2.fit_predict(X)

# Get the labels and use them in your plot
print(y_predict2)

plt.scatter(X[y_predict2 == 0, 0], X[y_predict2 == 0, 1], s = 10, c = '#fc2403', label = 'Cluster 1')
plt.scatter(X[y_predict2 == 1, 0], X[y_predict2 == 1, 1], s = 10, c = '#fc6203', label = 'Cluster 2')
plt.scatter(X[y_predict2 == 2, 0], X[y_predict2 == 2, 1], s = 10, c = '#fcad03', label = 'Cluster 3')
plt.scatter(X[y_predict2 == 3, 0], X[y_predict2 == 3, 1], s = 10, c = '#fceb03', label = 'Cluster 4')
plt.scatter(X[y_predict2 == 4, 0], X[y_predict2 == 4, 1], s = 10, c = '#befc03', label = 'Cluster 5')
plt.scatter(X[y_predict2 == 5, 0], X[y_predict2 == 5, 1], s = 10, c = '#4afc03', label = 'Cluster 6')
plt.scatter(X[y_predict2 == 6, 0], X[y_predict2 == 6, 1], s = 10, c = '#03fc8c', label = 'Cluster 7')
plt.scatter(X[y_predict2 == 7, 0], X[y_predict2 == 7, 1], s = 10, c = '#03fcdf', label = 'Cluster 8')
plt.scatter(X[y_predict2 == 8, 0], X[y_predict2 == 8, 1], s = 10, c = '#03dbfc', label = 'Cluster 9')
plt.scatter(X[y_predict2 == 9, 0], X[y_predict2 == 9, 1], s = 10, c = '#0388fc', label = 'Cluster 10')
plt.scatter(X[y_predict2 == 10, 0], X[y_predict2 == 10, 1], s = 10, c = '#032cfc', label = 'Cluster 11')
plt.scatter(X[y_predict2 == 11, 0], X[y_predict2 == 11, 1], s = 10, c = '#7703fc', label = 'Cluster 12')
plt.scatter(X[y_predict2 == 12, 0], X[y_predict2 == 12, 1], s = 10, c = '#ad03fc', label = 'Cluster 13')
plt.scatter(X[y_predict2 == 13, 0], X[y_predict2 == 13, 1], s = 10, c = '#fc03f4', label = 'Cluster 14')
plt.scatter(X[y_predict2 == 14, 0], X[y_predict2 == 14, 1], s = 10, c = '#fc03ad', label = 'Cluster 15')
plt.show()
# Out:
# [3 3 3 ... 5 5 5]

# %%
# Define model
aggl_model_4 = AgglomerativeClustering(n_clusters = 15, affinity = 'manhattan', linkage = 'complete')

# Use the fit_predict() function
y_predict4 = aggl_model_4.fit_predict(X)

# Get the labels and use them in your plot
print(y_predict4)

plt.scatter(X[y_predict4 == 0, 0], X[y_predict4 == 0, 1], s = 10, c = '#fc2403', label = 'Cluster 1')
plt.scatter(X[y_predict4 == 1, 0], X[y_predict4 == 1, 1], s = 10, c = '#fc6203', label = 'Cluster 2')
plt.scatter(X[y_predict4 == 2, 0], X[y_predict4 == 2, 1], s = 10, c = '#fcad03', label = 'Cluster 3')
plt.scatter(X[y_predict4 == 3, 0], X[y_predict4 == 3, 1], s = 10, c = '#fceb03', label = 'Cluster 4')
plt.scatter(X[y_predict4 == 4, 0], X[y_predict4 == 4, 1], s = 10, c = '#befc03', label = 'Cluster 5')
plt.scatter(X[y_predict4 == 5, 0], X[y_predict4 == 5, 1], s = 10, c = '#4afc03', label = 'Cluster 6')
plt.scatter(X[y_predict4 == 6, 0], X[y_predict4 == 6, 1], s = 10, c = '#03fc8c', label = 'Cluster 7')
plt.scatter(X[y_predict4 == 7, 0], X[y_predict4 == 7, 1], s = 10, c = '#03fcdf', label = 'Cluster 8')
plt.scatter(X[y_predict4 == 8, 0], X[y_predict4 == 8, 1], s = 10, c = '#03dbfc', label = 'Cluster 9')
plt.scatter(X[y_predict4 == 9, 0], X[y_predict4 == 9, 1], s = 10, c = '#0388fc', label = 'Cluster 10')
plt.scatter(X[y_predict4 == 10, 0], X[y_predict4 == 10, 1], s = 10, c = '#032cfc', label = 'Cluster 11')
plt.scatter(X[y_predict4 == 11, 0], X[y_predict4 == 11, 1], s = 10, c = '#7703fc', label = 'Cluster 12')
plt.scatter(X[y_predict4 == 12, 0], X[y_predict4 == 12, 1], s = 10, c = '#ad03fc', label = 'Cluster 13')
plt.scatter(X[y_predict4 == 13, 0], X[y_predict4 == 13, 1], s = 10, c = '#fc03f4', label = 'Cluster 14')
plt.scatter(X[y_predict4 == 14, 0], X[y_predict4 == 14, 1], s = 10, c = '#fc03ad', label = 'Cluster 15')
plt.show()
# Out:
# [ 3  3  3 ...  1 13  1]

# %%
# Expected plot for TO DO2

# %% [markdown]
# Using the 'euclidean' affinity and the 'ward' linkage seems to have had the most natural looking clustering results, with clusters that look like they were chosen by a human.
# Moving on to the second test ('euclidean' affinity + 'complete' linkage), the colors seem to have shifted, but that is because the centroids of each cluster are randomly assigned every time the algorithm is initiated. The overall shapes of the clusters have been maintained, however. There is just one exception: the cyan cluster seems to 'steal' some of the pink cluster in the bottom right part of this graph.
# The last version ('manhattan' affinity + 'complete' linkage) is very similar as far as overall clusters formed, but it seems to have the most 'mistakes'. In the bottom right corner, two clusters seem to have been combined into one (lime green) and, at the top of the graph, the purple and tangerine clusters both lose some elements to a newly formed pink cluster.

# %% [markdown]
# **TO DO3**: Use the _Nearest Centroid_ [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.NearestCentroid.html) to compute the centroids of each cluster.

# %%
# TO DO3
from sklearn.neighbors import NearestCentroid
# Expected Output:
clf = NearestCentroid()
clf.fit(X, y_predict1)
centroids = clf.centroids_
print('Centroids:')
print(centroids)
# Out:
# Centroids:
# [[858523.47107438 549109.0137741 ]
#  [321607.60349854 161194.23323615]
#  [672400.67597765 861555.2849162 ]
#  [619663.6884273  398658.75074184]
#  [140019.83526012 558305.60115607]
#  [417799.69426752 787001.99363057]
#  [399223.625      404923.23579545]
#  [337858.94189602 562276.80428135]
#  [167727.3880597  348147.6       ]
#  [508441.62931034 176054.77873563]
#  [823717.6744186  733102.37209302]
#  [244654.8856305  847642.04105572]
#  [606060.5959596  574146.15824916]
#  [802138.44551282 319314.90384615]
#  [852675.82769231 157386.94461538]]

# %% [markdown]
# **TO DO4:** Iterate through the obtained labels and visualise each cluster with its corresponding centroid.

# %%
unique_labels = np.unique(labels)

#TO DO 4

plt.scatter(X[y_predict1 == 0, 0], X[y_predict1 == 0, 1], s = 10, c = '#fc2403', label = 'Cluster 1')
plt.scatter(X[y_predict1 == 1, 0], X[y_predict1 == 1, 1], s = 10, c = '#fc6203', label = 'Cluster 2')
plt.scatter(X[y_predict1 == 2, 0], X[y_predict1 == 2, 1], s = 10, c = '#fcad03', label = 'Cluster 3')
plt.scatter(X[y_predict1 == 3, 0], X[y_predict1 == 3, 1], s = 10, c = '#fceb03', label = 'Cluster 4')
plt.scatter(X[y_predict1 == 4, 0], X[y_predict1 == 4, 1], s = 10, c = '#befc03', label = 'Cluster 5')
plt.scatter(X[y_predict1 == 5, 0], X[y_predict1 == 5, 1], s = 10, c = '#4afc03', label = 'Cluster 6')
plt.scatter(X[y_predict1 == 6, 0], X[y_predict1 == 6, 1], s = 10, c = '#03fc8c', label = 'Cluster 7')
plt.scatter(X[y_predict1 == 7, 0], X[y_predict1 == 7, 1], s = 10, c = '#03fcdf', label = 'Cluster 8')
plt.scatter(X[y_predict1 == 8, 0], X[y_predict1 == 8, 1], s = 10, c = '#03dbfc', label = 'Cluster 9')
plt.scatter(X[y_predict1 == 9, 0], X[y_predict1 == 9, 1], s = 10, c = '#0388fc', label = 'Cluster 10')
plt.scatter(X[y_predict1 == 10, 0], X[y_predict1 == 10, 1], s = 10, c = '#032cfc', label = 'Cluster 11')
plt.scatter(X[y_predict1 == 11, 0], X[y_predict1 == 11, 1], s = 10, c = '#7703fc', label = 'Cluster 12')
plt.scatter(X[y_predict1 == 12, 0], X[y_predict1 == 12, 1], s = 10, c = '#ad03fc', label = 'Cluster 13')
plt.scatter(X[y_predict1 == 13, 0], X[y_predict1 == 13, 1], s = 10, c = '#fc03f4', label = 'Cluster 14')
plt.scatter(X[y_predict1 == 14, 0], X[y_predict1 == 14, 1], s = 10, c = '#fc03ad', label = 'Cluster 15')

plt.scatter(centroids[:,0], centroids[:,1], s = 10, c = '#cf173f')
    
plt.show()

# %%
# Expected Output:

# %% [markdown]
# ## K-Means
#
# Please refer to this [document](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html) for more information.

# %% [markdown]
# ### Task 1
#
# Play around with `data.txt` and:
# * **TO DO1**: Apply the _K-Means Clustering_ algorithm and generate 15 clusters;
# * **TO DO2**: Write down your observations for the `algorithm` parameter (_"full"_ or _"elkan"_);
# * **TO DO3**: Compute the centroids for each cluster;
# * **TO DO4**: Visualise the obtained clusters with their corresponding centroids.
#
# _Note:_ At the end of this task, please use the `markdown` option provided in the notebook for your observations.

# %%
# TO DO1
from sklearn.cluster import KMeans
kmeans1 = KMeans(n_clusters = 15, algorithm = 'full')
y_kmeans1 = kmeans1.fit_predict(X)

plt.scatter(X[y_kmeans1 == 0, 0], X[y_kmeans1 == 0, 1], s = 10, c = '#fc2403', label = 'Cluster 1')
plt.scatter(X[y_kmeans1 == 1, 0], X[y_kmeans1 == 1, 1], s = 10, c = '#fc6203', label = 'Cluster 2')
plt.scatter(X[y_kmeans1 == 2, 0], X[y_kmeans1 == 2, 1], s = 10, c = '#fcad03', label = 'Cluster 3')
plt.scatter(X[y_kmeans1 == 3, 0], X[y_kmeans1 == 3, 1], s = 10, c = '#fceb03', label = 'Cluster 4')
plt.scatter(X[y_kmeans1 == 4, 0], X[y_kmeans1 == 4, 1], s = 10, c = '#befc03', label = 'Cluster 5')
plt.scatter(X[y_kmeans1 == 5, 0], X[y_kmeans1 == 5, 1], s = 10, c = '#4afc03', label = 'Cluster 6')
plt.scatter(X[y_kmeans1 == 6, 0], X[y_kmeans1 == 6, 1], s = 10, c = '#03fc8c', label = 'Cluster 7')
plt.scatter(X[y_kmeans1 == 7, 0], X[y_kmeans1 == 7, 1], s = 10, c = '#03fcdf', label = 'Cluster 8')
plt.scatter(X[y_kmeans1 == 8, 0], X[y_kmeans1 == 8, 1], s = 10, c = '#03dbfc', label = 'Cluster 9')
plt.scatter(X[y_kmeans1 == 9, 0], X[y_kmeans1 == 9, 1], s = 10, c = '#0388fc', label = 'Cluster 10')
plt.scatter(X[y_kmeans1 == 10, 0], X[y_kmeans1 == 10, 1], s = 10, c = '#032cfc', label = 'Cluster 11')
plt.scatter(X[y_kmeans1 == 11, 0], X[y_kmeans1 == 11, 1], s = 10, c = '#7703fc', label = 'Cluster 12')
plt.scatter(X[y_kmeans1 == 12, 0], X[y_kmeans1 == 12, 1], s = 10, c = '#ad03fc', label = 'Cluster 13')
plt.scatter(X[y_kmeans1 == 13, 0], X[y_kmeans1 == 13, 1], s = 10, c = '#fc03f4', label = 'Cluster 14')
plt.scatter(X[y_kmeans1 == 14, 0], X[y_kmeans1 == 14, 1], s = 10, c = '#fc03ad', label = 'Cluster 15')
plt.show()

# %%
kmeans2 = KMeans(n_clusters = 15, algorithm = 'elkan')
y_kmeans2 = kmeans2.fit_predict(X)

plt.scatter(X[y_kmeans2 == 0, 0], X[y_kmeans2 == 0, 1], s = 10, c = '#fc2403', label = 'Cluster 1')
plt.scatter(X[y_kmeans2 == 1, 0], X[y_kmeans2 == 1, 1], s = 10, c = '#fc6203', label = 'Cluster 2')
plt.scatter(X[y_kmeans2 == 2, 0], X[y_kmeans2 == 2, 1], s = 10, c = '#fcad03', label = 'Cluster 3')
plt.scatter(X[y_kmeans2 == 3, 0], X[y_kmeans2 == 3, 1], s = 10, c = '#fceb03', label = 'Cluster 4')
plt.scatter(X[y_kmeans2 == 4, 0], X[y_kmeans2 == 4, 1], s = 10, c = '#befc03', label = 'Cluster 5')
plt.scatter(X[y_kmeans2 == 5, 0], X[y_kmeans2 == 5, 1], s = 10, c = '#4afc03', label = 'Cluster 6')
plt.scatter(X[y_kmeans2 == 6, 0], X[y_kmeans2 == 6, 1], s = 10, c = '#03fc8c', label = 'Cluster 7')
plt.scatter(X[y_kmeans2 == 7, 0], X[y_kmeans2 == 7, 1], s = 10, c = '#03fcdf', label = 'Cluster 8')
plt.scatter(X[y_kmeans2 == 8, 0], X[y_kmeans2 == 8, 1], s = 10, c = '#03dbfc', label = 'Cluster 9')
plt.scatter(X[y_kmeans2 == 9, 0], X[y_kmeans2 == 9, 1], s = 10, c = '#0388fc', label = 'Cluster 10')
plt.scatter(X[y_kmeans2 == 10, 0], X[y_kmeans2 == 10, 1], s = 10, c = '#032cfc', label = 'Cluster 11')
plt.scatter(X[y_kmeans2 == 11, 0], X[y_kmeans2 == 11, 1], s = 10, c = '#7703fc', label = 'Cluster 12')
plt.scatter(X[y_kmeans2 == 12, 0], X[y_kmeans2 == 12, 1], s = 10, c = '#ad03fc', label = 'Cluster 13')
plt.scatter(X[y_kmeans2 == 13, 0], X[y_kmeans2 == 13, 1], s = 10, c = '#fc03f4', label = 'Cluster 14')
plt.scatter(X[y_kmeans2 == 14, 0], X[y_kmeans2 == 14, 1], s = 10, c = '#fc03ad', label = 'Cluster 15')
plt.show()

# %% [markdown]
# #TO DO2: They look exactly the same to me, whether I used 'full' or 'elkan' as the algorithm.

# %%
# TO DO3
clf_k = NearestCentroid()
clf_k.fit(X, y_kmeans1)
centroids_k = clf_k.centroids_
print('Centroids:')
print(centroids_k)
# Out:
# Centroids:
# [[320602.55       161521.85      ]
#  [417799.69426752 787001.99363057]
#  [852058.45259939 157685.52293578]
#  [398870.04843305 404924.06552707]
#  [858947.9713467  546259.65902579]
#  [167856.14071856 347812.71556886]
#  [670929.06818182 862765.73295455]
#  [606380.41554054 574534.59121622]
#  [507818.31339031 175610.41595442]
#  [139682.37572254 558123.40462428]
#  [801616.78164557 321123.34177215]
#  [244654.8856305  847642.04105572]
#  [337565.11890244 562157.17682927]
#  [617926.67761194 399415.94925373]
#  [823421.2507837  731145.27272727]]

# %%
# Expected Output:
centroids
# Out:
# array([[320602.55      , 161521.85      ],
#        [858947.97134671, 546259.65902579],
#        [337264.76291793, 562123.37993921],
#        [417799.69426752, 787001.99363057],
#        [852058.45259939, 157685.52293578],
#        [507818.31339031, 175610.41595441],
#        [606380.41554054, 574534.59121622],
#        [139395.22898551, 558143.94202899],
#        [670929.06818182, 862765.73295454],
#        [244654.8856305 , 847642.04105572],
#        [801616.78164557, 321123.34177215],
#        [617926.67761194, 399415.94925373],
#        [398870.04843305, 404924.06552707],
#        [823421.2507837 , 731145.27272727],
#        [167856.14071856, 347812.71556886]])

# %%
unique_labels = np.unique(labels)

# TO DO4
plt.scatter(X[y_kmeans1 == 0, 0], X[y_kmeans1 == 0, 1], s = 10, c = '#fc2403', label = 'Cluster 1')
plt.scatter(X[y_kmeans1 == 1, 0], X[y_kmeans1 == 1, 1], s = 10, c = '#fc6203', label = 'Cluster 2')
plt.scatter(X[y_kmeans1 == 2, 0], X[y_kmeans1 == 2, 1], s = 10, c = '#fcad03', label = 'Cluster 3')
plt.scatter(X[y_kmeans1 == 3, 0], X[y_kmeans1 == 3, 1], s = 10, c = '#fceb03', label = 'Cluster 4')
plt.scatter(X[y_kmeans1 == 4, 0], X[y_kmeans1 == 4, 1], s = 10, c = '#befc03', label = 'Cluster 5')
plt.scatter(X[y_kmeans1 == 5, 0], X[y_kmeans1 == 5, 1], s = 10, c = '#4afc03', label = 'Cluster 6')
plt.scatter(X[y_kmeans1 == 6, 0], X[y_kmeans1 == 6, 1], s = 10, c = '#03fc8c', label = 'Cluster 7')
plt.scatter(X[y_kmeans1 == 7, 0], X[y_kmeans1 == 7, 1], s = 10, c = '#03fcdf', label = 'Cluster 8')
plt.scatter(X[y_kmeans1 == 8, 0], X[y_kmeans1 == 8, 1], s = 10, c = '#03dbfc', label = 'Cluster 9')
plt.scatter(X[y_kmeans1 == 9, 0], X[y_kmeans1 == 9, 1], s = 10, c = '#0388fc', label = 'Cluster 10')
plt.scatter(X[y_kmeans1 == 10, 0], X[y_kmeans1 == 10, 1], s = 10, c = '#032cfc', label = 'Cluster 11')
plt.scatter(X[y_kmeans1 == 11, 0], X[y_kmeans1 == 11, 1], s = 10, c = '#7703fc', label = 'Cluster 12')
plt.scatter(X[y_kmeans1 == 12, 0], X[y_kmeans1 == 12, 1], s = 10, c = '#ad03fc', label = 'Cluster 13')
plt.scatter(X[y_kmeans1 == 13, 0], X[y_kmeans1 == 13, 1], s = 10, c = '#fc03f4', label = 'Cluster 14')
plt.scatter(X[y_kmeans1 == 14, 0], X[y_kmeans1 == 14, 1], s = 10, c = '#fc03ad', label = 'Cluster 15')

plt.scatter(centroids_k[:,0], centroids_k[:,1], s = 10, c = '#cf173f')
    
plt.show()

# %% [markdown]
# ### Task 2
#
# Try to modify the number of clusters for `data2.txt` and write down your observations for the _Agglomerative Hierarchical Clustering_ model.

# %%
# First, I will load data for this exercise and try to estimate the optimal number of clusters
data2_txt = np.loadtxt('data2.txt', usecols=(0, 1), skiprows=1)
plt.scatter(data2_txt[:,0], data2_txt[:,1], s = 10)

# %%
#To me, it looks like 2 clusters would be in order
X2 = data2_txt
aggl_model_4 = AgglomerativeClustering(n_clusters = 2, affinity = 'euclidean', linkage = 'ward')
y_predict4 = aggl_model_4.fit_predict(X2)

#I will also plot the centroids
clf_4 = NearestCentroid()
clf_4.fit(X2, y_predict4)
centroids_4 = clf_4.centroids_

plt.scatter(X2[y_predict4 == 0, 0], X2[y_predict4 == 0, 1], s = 10, c = '#d900ff', label = 'Cluster 1')
plt.scatter(X2[y_predict4 == 1, 0], X2[y_predict4 == 1, 1], s = 10, c = '#0084ff', label = 'Cluster 2')
plt.scatter(centroids_4[:,0], centroids_4[:,1], s = 50, c = '#ffd900')
plt.legend()
plt.show()

# %%
#I will also try it with 3 clusters
aggl_model_5 = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'ward')
y_predict5 = aggl_model_5.fit_predict(X2)

clf_5 = NearestCentroid()
clf_5.fit(X2, y_predict5)
centroids_5 = clf_5.centroids_

plt.scatter(X2[y_predict5 == 0, 0], X2[y_predict5 == 0, 1], s = 10, c = '#d900ff', label = 'Cluster 1')
plt.scatter(X2[y_predict5 == 1, 0], X2[y_predict5 == 1, 1], s = 10, c = '#0084ff', label = 'Cluster 2')
plt.scatter(X2[y_predict5 == 2, 0], X2[y_predict5 == 2, 1], s = 10, c = '#00f2ff', label = 'Cluster 3')
plt.scatter(centroids_5[:,0], centroids_5[:,1], s = 50, c = '#ffd900')
plt.legend()
plt.show()

# %%
#One more time with 4 clusters
aggl_model_6 = AgglomerativeClustering(n_clusters = 4, affinity = 'euclidean', linkage = 'ward')
y_predict6 = aggl_model_6.fit_predict(X2)

clf_6 = NearestCentroid()
clf_6.fit(X2, y_predict6)
centroids_6 = clf_6.centroids_

plt.scatter(X2[y_predict6 == 0, 0], X2[y_predict6 == 0, 1], s = 10, c = '#d900ff', label = 'Cluster 1')
plt.scatter(X2[y_predict6 == 1, 0], X2[y_predict6 == 1, 1], s = 10, c = '#0084ff', label = 'Cluster 2')
plt.scatter(X2[y_predict6 == 2, 0], X2[y_predict6 == 2, 1], s = 10, c = '#00f2ff', label = 'Cluster 3')
plt.scatter(X2[y_predict6 == 3, 0], X2[y_predict6 == 3, 1], s = 10, c = '#b3ff00', label = 'Cluster 4')
plt.scatter(centroids_6[:,0], centroids_6[:,1], s = 50, c = '#ffd900')
plt.legend()
plt.show()

# %% [markdown]
# Observations: This is very subjective. I think I could keep going and trying with more clusters, but, to my human eye, none of them seems right because the data seems to be in one big cluster, or at most two.

# %% [markdown]
# Feedback: This was very easy for me haha. It's the quickest AI lab yet. I enjoyed it!
